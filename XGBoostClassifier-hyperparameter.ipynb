# %% [markdown]
# # Starbucks Capstone Challenge

# %% [markdown]
# ## XGBoost Classifier (Hyperparameter Tuning)

# %%
import pandas as pd
import boto3
import sagemaker
import os

# %% [markdown]
# ### Upload the data to S3

# %%
data_dir =  'ML_data'
prefix = 'sagemaker/ML-tuning-HL'

session = sagemaker.Session()
val_location = session.upload_data(os.path.join(data_dir, 'val.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### Import and upload the test data

# %%
test_data = pd.read_csv(os.path.join(data_dir,'test.csv'), header= None)

# %%
test_y, test_x = test_data.iloc[:,0], test_data.iloc[:,1:]

# %%
pd.DataFrame(test_x).to_csv(os.path.join(data_dir, 'test_x.csv'), header=False, index=False)
test_location = session.upload_data(os.path.join(data_dir, 'test_x.csv'), key_prefix=prefix)

# %% [markdown]
# ### Build and Train XGBoost Classifier

# %%
from sagemaker import get_execution_role
role = get_execution_role()

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %%
xgb = sagemaker.estimator.Estimator(container,
                                   role,
                                   train_instance_count=1,
                                   train_instance_type='ml.m4.xlarge',
                                   output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                   sagemaker_session = session)

xgb.set_hyperparameters(max_depth=5,
                       eta=0.2,
                       gamma=4,
                       min_child_weight=6,
                       subsample=0.8,
                       silent=0,
                       objective='binary:logistic',
                       early_stopping_rounds=10,
                       num_round=500)

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb,
                                             objective_metric_name = 'validation:rmse',
                                             objective_type = 'Minimize',
                                             max_jobs = 20,
                                             max_parallel_jobs = 3,
                                             hyperparameter_ranges ={
                                                 'max_depth':IntegerParameter(3, 12),
                                                 'eta':ContinuousParameter(0.05, 0.5),
                                                 'min_child_weight':IntegerParameter(2, 8),
                                                 'subsample':ContinuousParameter(0.5, 0.9),
                                                 'gamma':ContinuousParameter(0, 10),
                                             })

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# ........................................................

# %%
xgb_hyperparameter_tuner.best_training_job()

# %% [markdown]
# ### Test the model

# %%
xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2020-06-06 23:52:56 Starting - Preparing the instances for training
# 2020-06-06 23:52:56 Downloading - Downloading input data
# 2020-06-06 23:52:56 Training - Training image download completed. Training in progress.
# 2020-06-06 23:52:56 Uploading - Uploading generated training model
# 2020-06-06 23:52:56 Completed - Training job completedArguments: train
# [2020-06-06:23:52:29:INFO] Running standalone xgboost training.
# [2020-06-06:23:52:29:INFO] Setting up HPO optimized metric to be : rmse
# [2020-06-06:23:52:29:INFO] File size need to be processed in the node: 10.16mb. Available memory size in the node: 8468.4mb
# [2020-06-06:23:52:29:INFO] Determined delimiter of CSV input is ','
# [23:52:29] S3DistributionType set as FullyReplicated
# [23:52:29] 42641x18 matrix with 767538 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-06-06:23:52:29:INFO] Determined delimiter of CSV input is ','
# [23:52:29] S3DistributionType set as FullyReplicated
# [23:52:29] 10661x18 matrix with 191898 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2084 extra nodes, 58 pruned nodes, max_depth=12
# [0]#011train-rmse:0.463741#011validation-rmse:0.470503
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1974 extra nodes, 52 pruned nodes, max_depth=12
# [1]#011train-rmse:0.437912#011validation-rmse:0.450279
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2008 extra nodes, 66 pruned nodes, max_depth=12
# [2]#011train-rmse:0.418301#011validation-rmse:0.436263
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1920 extra nodes, 64 pruned nodes, max_depth=12
# [3]#011train-rmse:0.403622#011validation-rmse:0.426802
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1900 extra nodes, 64 pruned nodes, max_depth=12
# [4]#011train-rmse:0.3918#011validation-rmse:0.419728
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2032 extra nodes, 70 pruned nodes, max_depth=12
# [5]#011train-rmse:0.381492#011validation-rmse:0.41415
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1822 extra nodes, 78 pruned nodes, max_depth=12
# [6]#011train-rmse:0.373552#011validation-rmse:0.410042
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1800 extra nodes, 46 pruned nodes, max_depth=12
# [7]#011train-rmse:0.366671#011validation-rmse:0.40645
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1822 extra nodes, 68 pruned nodes, max_depth=12
# [8]#011train-rmse:0.360261#011validation-rmse:0.404189
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1632 extra nodes, 66 pruned nodes, max_depth=12
# [9]#011train-rmse:0.354486#011validation-rmse:0.402123
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1632 extra nodes, 50 pruned nodes, max_depth=12
# [10]#011train-rmse:0.34952#011validation-rmse:0.400577
# [23:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1398 extra nodes, 76 pruned nodes, max_depth=12
# [11]#011train-rmse:0.345301#011validation-rmse:0.398955
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1566 extra nodes, 74 pruned nodes, max_depth=12
# [12]#011train-rmse:0.340734#011validation-rmse:0.397391
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1334 extra nodes, 56 pruned nodes, max_depth=12
# [13]#011train-rmse:0.336932#011validation-rmse:0.396301
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1216 extra nodes, 42 pruned nodes, max_depth=12
# [14]#011train-rmse:0.333677#011validation-rmse:0.395532
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1114 extra nodes, 40 pruned nodes, max_depth=12
# [15]#011train-rmse:0.330579#011validation-rmse:0.3948
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1348 extra nodes, 44 pruned nodes, max_depth=12
# [16]#011train-rmse:0.326381#011validation-rmse:0.393324
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1010 extra nodes, 34 pruned nodes, max_depth=12
# [17]#011train-rmse:0.323445#011validation-rmse:0.392224
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1034 extra nodes, 54 pruned nodes, max_depth=12
# [18]#011train-rmse:0.320474#011validation-rmse:0.391044
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1068 extra nodes, 38 pruned nodes, max_depth=12
# [19]#011train-rmse:0.317333#011validation-rmse:0.389951
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 674 extra nodes, 30 pruned nodes, max_depth=12
# [20]#011train-rmse:0.315518#011validation-rmse:0.389389
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1212 extra nodes, 50 pruned nodes, max_depth=12
# [21]#011train-rmse:0.312245#011validation-rmse:0.388379
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1230 extra nodes, 34 pruned nodes, max_depth=12
# [22]#011train-rmse:0.308654#011validation-rmse:0.387487
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 972 extra nodes, 56 pruned nodes, max_depth=12
# [23]#011train-rmse:0.305997#011validation-rmse:0.386422
# [23:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 640 extra nodes, 26 pruned nodes, max_depth=12
# [24]#011train-rmse:0.304261#011validation-rmse:0.385771
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1176 extra nodes, 52 pruned nodes, max_depth=12
# [25]#011train-rmse:0.301423#011validation-rmse:0.384869
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 668 extra nodes, 28 pruned nodes, max_depth=12
# [26]#011train-rmse:0.299534#011validation-rmse:0.384159
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1158 extra nodes, 60 pruned nodes, max_depth=12
# [27]#011train-rmse:0.296666#011validation-rmse:0.383485
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 962 extra nodes, 22 pruned nodes, max_depth=12
# [28]#011train-rmse:0.294315#011validation-rmse:0.38268
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 934 extra nodes, 60 pruned nodes, max_depth=12
# [29]#011train-rmse:0.291876#011validation-rmse:0.382012
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 732 extra nodes, 28 pruned nodes, max_depth=12
# [30]#011train-rmse:0.290004#011validation-rmse:0.381339
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1174 extra nodes, 58 pruned nodes, max_depth=12
# [31]#011train-rmse:0.286556#011validation-rmse:0.380092
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 798 extra nodes, 28 pruned nodes, max_depth=12
# [32]#011train-rmse:0.284657#011validation-rmse:0.379194
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1292 extra nodes, 98 pruned nodes, max_depth=12
# [33]#011train-rmse:0.281794#011validation-rmse:0.378603
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 894 extra nodes, 52 pruned nodes, max_depth=12
# [34]#011train-rmse:0.279999#011validation-rmse:0.378201
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 692 extra nodes, 26 pruned nodes, max_depth=12
# [35]#011train-rmse:0.278386#011validation-rmse:0.378006
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1138 extra nodes, 46 pruned nodes, max_depth=12
# [36]#011train-rmse:0.275283#011validation-rmse:0.377012
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 890 extra nodes, 42 pruned nodes, max_depth=12
# [37]#011train-rmse:0.27344#011validation-rmse:0.376337
# [23:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 854 extra nodes, 36 pruned nodes, max_depth=12
# [38]#011train-rmse:0.271727#011validation-rmse:0.376021
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 12 pruned nodes, max_depth=12
# [39]#011train-rmse:0.270926#011validation-rmse:0.375742
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 848 extra nodes, 50 pruned nodes, max_depth=12
# [40]#011train-rmse:0.269194#011validation-rmse:0.37541
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 42 pruned nodes, max_depth=12
# [41]#011train-rmse:0.268181#011validation-rmse:0.375184
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 814 extra nodes, 60 pruned nodes, max_depth=12
# [42]#011train-rmse:0.266394#011validation-rmse:0.374268
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 884 extra nodes, 36 pruned nodes, max_depth=12
# [43]#011train-rmse:0.264179#011validation-rmse:0.373282
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 656 extra nodes, 48 pruned nodes, max_depth=12
# [44]#011train-rmse:0.262861#011validation-rmse:0.372727
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 490 extra nodes, 28 pruned nodes, max_depth=12
# [45]#011train-rmse:0.261977#011validation-rmse:0.37252
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 690 extra nodes, 38 pruned nodes, max_depth=12
# [46]#011train-rmse:0.26053#011validation-rmse:0.371954
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 50 pruned nodes, max_depth=12
# [47]#011train-rmse:0.259469#011validation-rmse:0.371725
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 994 extra nodes, 52 pruned nodes, max_depth=12
# [48]#011train-rmse:0.257276#011validation-rmse:0.371147
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 712 extra nodes, 70 pruned nodes, max_depth=12
# [49]#011train-rmse:0.256057#011validation-rmse:0.370883
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 688 extra nodes, 38 pruned nodes, max_depth=12
# [50]#011train-rmse:0.254663#011validation-rmse:0.370645
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 982 extra nodes, 64 pruned nodes, max_depth=12
# [51]#011train-rmse:0.252777#011validation-rmse:0.370166
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 796 extra nodes, 54 pruned nodes, max_depth=12
# [52]#011train-rmse:0.251058#011validation-rmse:0.369834
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 984 extra nodes, 84 pruned nodes, max_depth=12
# [53]#011train-rmse:0.249352#011validation-rmse:0.36921
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 850 extra nodes, 50 pruned nodes, max_depth=12
# [54]#011train-rmse:0.247729#011validation-rmse:0.368728
# [23:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1174 extra nodes, 76 pruned nodes, max_depth=12
# [55]#011train-rmse:0.245233#011validation-rmse:0.368032
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 858 extra nodes, 50 pruned nodes, max_depth=12
# [56]#011train-rmse:0.243379#011validation-rmse:0.367394
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1202 extra nodes, 112 pruned nodes, max_depth=12
# [57]#011train-rmse:0.241016#011validation-rmse:0.36667
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1082 extra nodes, 66 pruned nodes, max_depth=12
# [58]#011train-rmse:0.23897#011validation-rmse:0.365904
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 990 extra nodes, 56 pruned nodes, max_depth=12
# [59]#011train-rmse:0.237154#011validation-rmse:0.365183
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 932 extra nodes, 74 pruned nodes, max_depth=12
# [60]#011train-rmse:0.235496#011validation-rmse:0.36453
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 584 extra nodes, 52 pruned nodes, max_depth=12
# [61]#011train-rmse:0.2346#011validation-rmse:0.364336
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 830 extra nodes, 58 pruned nodes, max_depth=12
# [62]#011train-rmse:0.233194#011validation-rmse:0.364067
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1118 extra nodes, 86 pruned nodes, max_depth=12
# [63]#011train-rmse:0.230914#011validation-rmse:0.363513
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 880 extra nodes, 66 pruned nodes, max_depth=12
# [64]#011train-rmse:0.229316#011validation-rmse:0.363212
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1090 extra nodes, 64 pruned nodes, max_depth=12
# [65]#011train-rmse:0.227406#011validation-rmse:0.362522
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 860 extra nodes, 72 pruned nodes, max_depth=12
# [66]#011train-rmse:0.225748#011validation-rmse:0.361905
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1040 extra nodes, 96 pruned nodes, max_depth=12
# [67]#011train-rmse:0.223703#011validation-rmse:0.361327
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 660 extra nodes, 38 pruned nodes, max_depth=12
# [68]#011train-rmse:0.222599#011validation-rmse:0.36089
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1060 extra nodes, 80 pruned nodes, max_depth=12
# [69]#011train-rmse:0.220702#011validation-rmse:0.360533
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 976 extra nodes, 70 pruned nodes, max_depth=12
# [70]#011train-rmse:0.218958#011validation-rmse:0.360046
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 782 extra nodes, 62 pruned nodes, max_depth=12
# [71]#011train-rmse:0.21763#011validation-rmse:0.359609
# [23:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 738 extra nodes, 46 pruned nodes, max_depth=12
# [72]#011train-rmse:0.21633#011validation-rmse:0.358953
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 34 pruned nodes, max_depth=12
# [73]#011train-rmse:0.215551#011validation-rmse:0.358646
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 834 extra nodes, 76 pruned nodes, max_depth=12
# [74]#011train-rmse:0.214356#011validation-rmse:0.358133
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 902 extra nodes, 108 pruned nodes, max_depth=12
# [75]#011train-rmse:0.212598#011validation-rmse:0.357597
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 900 extra nodes, 78 pruned nodes, max_depth=12
# [76]#011train-rmse:0.211126#011validation-rmse:0.357303
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 602 extra nodes, 54 pruned nodes, max_depth=12
# [77]#011train-rmse:0.21018#011validation-rmse:0.35721
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1010 extra nodes, 84 pruned nodes, max_depth=12
# [78]#011train-rmse:0.208685#011validation-rmse:0.356779
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 984 extra nodes, 74 pruned nodes, max_depth=12
# [79]#011train-rmse:0.206918#011validation-rmse:0.356358
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 648 extra nodes, 58 pruned nodes, max_depth=12
# [80]#011train-rmse:0.205931#011validation-rmse:0.356131
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 904 extra nodes, 76 pruned nodes, max_depth=12
# [81]#011train-rmse:0.204663#011validation-rmse:0.355658
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 682 extra nodes, 70 pruned nodes, max_depth=12
# [82]#011train-rmse:0.203723#011validation-rmse:0.355563
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1118 extra nodes, 102 pruned nodes, max_depth=12
# [83]#011train-rmse:0.201754#011validation-rmse:0.355406
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1132 extra nodes, 132 pruned nodes, max_depth=12
# [84]#011train-rmse:0.19981#011validation-rmse:0.355335
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 516 extra nodes, 72 pruned nodes, max_depth=12
# [85]#011train-rmse:0.199198#011validation-rmse:0.355319
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 38 pruned nodes, max_depth=12
# [86]#011train-rmse:0.198851#011validation-rmse:0.35528
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 826 extra nodes, 84 pruned nodes, max_depth=12
# [87]#011train-rmse:0.197525#011validation-rmse:0.35506
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 842 extra nodes, 90 pruned nodes, max_depth=12
# [88]#011train-rmse:0.196171#011validation-rmse:0.354561
# [23:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 712 extra nodes, 80 pruned nodes, max_depth=12
# [89]#011train-rmse:0.19505#011validation-rmse:0.354126
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 856 extra nodes, 64 pruned nodes, max_depth=12
# [90]#011train-rmse:0.193658#011validation-rmse:0.353834
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 696 extra nodes, 58 pruned nodes, max_depth=12
# [91]#011train-rmse:0.192622#011validation-rmse:0.35329
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 804 extra nodes, 88 pruned nodes, max_depth=12
# [92]#011train-rmse:0.191409#011validation-rmse:0.352716
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 896 extra nodes, 100 pruned nodes, max_depth=12
# [93]#011train-rmse:0.190214#011validation-rmse:0.35242
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1208 extra nodes, 122 pruned nodes, max_depth=12
# [94]#011train-rmse:0.18846#011validation-rmse:0.351879
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1006 extra nodes, 114 pruned nodes, max_depth=12
# [95]#011train-rmse:0.186958#011validation-rmse:0.351472
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 844 extra nodes, 90 pruned nodes, max_depth=12
# [96]#011train-rmse:0.185675#011validation-rmse:0.350946
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 676 extra nodes, 68 pruned nodes, max_depth=12
# [97]#011train-rmse:0.184764#011validation-rmse:0.350842
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 518 extra nodes, 76 pruned nodes, max_depth=12
# [98]#011train-rmse:0.184189#011validation-rmse:0.350672
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 824 extra nodes, 94 pruned nodes, max_depth=12
# [99]#011train-rmse:0.183043#011validation-rmse:0.350548
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 830 extra nodes, 120 pruned nodes, max_depth=12
# [100]#011train-rmse:0.18202#011validation-rmse:0.350486
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 958 extra nodes, 116 pruned nodes, max_depth=12
# [101]#011train-rmse:0.180585#011validation-rmse:0.35027
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 854 extra nodes, 92 pruned nodes, max_depth=12
# [102]#011train-rmse:0.179627#011validation-rmse:0.349981
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 700 extra nodes, 98 pruned nodes, max_depth=12
# [103]#011train-rmse:0.178777#011validation-rmse:0.349654
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 874 extra nodes, 80 pruned nodes, max_depth=12
# [104]#011train-rmse:0.177521#011validation-rmse:0.349146
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 804 extra nodes, 106 pruned nodes, max_depth=12
# [105]#011train-rmse:0.176446#011validation-rmse:0.348827
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1074 extra nodes, 178 pruned nodes, max_depth=12
# [106]#011train-rmse:0.174985#011validation-rmse:0.348217
# [23:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 876 extra nodes, 102 pruned nodes, max_depth=12
# [107]#011train-rmse:0.173808#011validation-rmse:0.347766
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 512 extra nodes, 80 pruned nodes, max_depth=12
# [108]#011train-rmse:0.173122#011validation-rmse:0.347675
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 700 extra nodes, 74 pruned nodes, max_depth=12
# [109]#011train-rmse:0.172267#011validation-rmse:0.347399
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 828 extra nodes, 90 pruned nodes, max_depth=12
# [110]#011train-rmse:0.171149#011validation-rmse:0.347108
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 804 extra nodes, 120 pruned nodes, max_depth=12
# [111]#011train-rmse:0.170137#011validation-rmse:0.346897
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 880 extra nodes, 114 pruned nodes, max_depth=12
# [112]#011train-rmse:0.16896#011validation-rmse:0.346879
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 872 extra nodes, 110 pruned nodes, max_depth=12
# [113]#011train-rmse:0.167864#011validation-rmse:0.346657
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 868 extra nodes, 148 pruned nodes, max_depth=12
# [114]#011train-rmse:0.16678#011validation-rmse:0.346225
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 806 extra nodes, 116 pruned nodes, max_depth=12
# [115]#011train-rmse:0.165745#011validation-rmse:0.34602
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 766 extra nodes, 126 pruned nodes, max_depth=12
# [116]#011train-rmse:0.164752#011validation-rmse:0.345802
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 822 extra nodes, 132 pruned nodes, max_depth=12
# [117]#011train-rmse:0.163756#011validation-rmse:0.345698
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 44 pruned nodes, max_depth=12
# [118]#011train-rmse:0.163271#011validation-rmse:0.345469
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 818 extra nodes, 140 pruned nodes, max_depth=12
# [119]#011train-rmse:0.162331#011validation-rmse:0.345176
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 846 extra nodes, 156 pruned nodes, max_depth=12
# [120]#011train-rmse:0.161276#011validation-rmse:0.344911
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 644 extra nodes, 168 pruned nodes, max_depth=12
# [121]#011train-rmse:0.160541#011validation-rmse:0.344673
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 640 extra nodes, 112 pruned nodes, max_depth=12
# [122]#011train-rmse:0.159853#011validation-rmse:0.3445
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 646 extra nodes, 134 pruned nodes, max_depth=12
# [123]#011train-rmse:0.15908#011validation-rmse:0.3442
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 902 extra nodes, 120 pruned nodes, max_depth=12
# [124]#011train-rmse:0.157995#011validation-rmse:0.344034
# [23:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 86 pruned nodes, max_depth=12
# [125]#011train-rmse:0.157598#011validation-rmse:0.343902
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 786 extra nodes, 106 pruned nodes, max_depth=12
# [126]#011train-rmse:0.156685#011validation-rmse:0.343627
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 86 pruned nodes, max_depth=12
# [127]#011train-rmse:0.156258#011validation-rmse:0.343465
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 786 extra nodes, 130 pruned nodes, max_depth=12
# [128]#011train-rmse:0.155214#011validation-rmse:0.343395
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 698 extra nodes, 128 pruned nodes, max_depth=12
# [129]#011train-rmse:0.154428#011validation-rmse:0.343247
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 572 extra nodes, 120 pruned nodes, max_depth=12
# [130]#011train-rmse:0.153841#011validation-rmse:0.343005
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 798 extra nodes, 164 pruned nodes, max_depth=12
# [131]#011train-rmse:0.152932#011validation-rmse:0.342615
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 668 extra nodes, 122 pruned nodes, max_depth=12
# [132]#011train-rmse:0.152118#011validation-rmse:0.342347
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 776 extra nodes, 144 pruned nodes, max_depth=12
# [133]#011train-rmse:0.151282#011validation-rmse:0.342251
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 572 extra nodes, 108 pruned nodes, max_depth=12
# [134]#011train-rmse:0.150574#011validation-rmse:0.34203
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 522 extra nodes, 102 pruned nodes, max_depth=12
# [135]#011train-rmse:0.149984#011validation-rmse:0.341836
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 586 extra nodes, 140 pruned nodes, max_depth=12
# [136]#011train-rmse:0.149364#011validation-rmse:0.341891
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 690 extra nodes, 140 pruned nodes, max_depth=12
# [137]#011train-rmse:0.14866#011validation-rmse:0.341779
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 154 pruned nodes, max_depth=12
# [138]#011train-rmse:0.148261#011validation-rmse:0.341752
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 128 pruned nodes, max_depth=12
# [139]#011train-rmse:0.147745#011validation-rmse:0.341645
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 816 extra nodes, 166 pruned nodes, max_depth=12
# [140]#011train-rmse:0.14674#011validation-rmse:0.341469
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 800 extra nodes, 182 pruned nodes, max_depth=12
# [141]#011train-rmse:0.145953#011validation-rmse:0.341398
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 610 extra nodes, 104 pruned nodes, max_depth=12
# [142]#011train-rmse:0.145239#011validation-rmse:0.341211
# [23:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 806 extra nodes, 152 pruned nodes, max_depth=12
# [143]#011train-rmse:0.144373#011validation-rmse:0.341011
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 124 pruned nodes, max_depth=12
# [144]#011train-rmse:0.144048#011validation-rmse:0.340902
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 680 extra nodes, 170 pruned nodes, max_depth=12
# [145]#011train-rmse:0.143414#011validation-rmse:0.340843
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 720 extra nodes, 134 pruned nodes, max_depth=12
# [146]#011train-rmse:0.142582#011validation-rmse:0.340624
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 554 extra nodes, 112 pruned nodes, max_depth=12
# [147]#011train-rmse:0.142124#011validation-rmse:0.340724
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 698 extra nodes, 120 pruned nodes, max_depth=12
# [148]#011train-rmse:0.141289#011validation-rmse:0.340747
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 862 extra nodes, 198 pruned nodes, max_depth=12
# [149]#011train-rmse:0.14029#011validation-rmse:0.340635
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 136 pruned nodes, max_depth=12
# [150]#011train-rmse:0.139888#011validation-rmse:0.340586
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 798 extra nodes, 224 pruned nodes, max_depth=12
# [151]#011train-rmse:0.139151#011validation-rmse:0.340436
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 818 extra nodes, 202 pruned nodes, max_depth=12
# [152]#011train-rmse:0.138399#011validation-rmse:0.340218
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 120 pruned nodes, max_depth=12
# [153]#011train-rmse:0.137975#011validation-rmse:0.340258
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 700 extra nodes, 144 pruned nodes, max_depth=12
# [154]#011train-rmse:0.137217#011validation-rmse:0.340149
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 124 pruned nodes, max_depth=12
# [155]#011train-rmse:0.136962#011validation-rmse:0.340067
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 590 extra nodes, 124 pruned nodes, max_depth=12
# [156]#011train-rmse:0.136413#011validation-rmse:0.339862
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 552 extra nodes, 154 pruned nodes, max_depth=12
# [157]#011train-rmse:0.135853#011validation-rmse:0.339812
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 658 extra nodes, 194 pruned nodes, max_depth=12
# [158]#011train-rmse:0.135225#011validation-rmse:0.339628
# [23:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 702 extra nodes, 166 pruned nodes, max_depth=12
# [159]#011train-rmse:0.134483#011validation-rmse:0.339226
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 654 extra nodes, 146 pruned nodes, max_depth=12
# [160]#011train-rmse:0.133817#011validation-rmse:0.339049
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 530 extra nodes, 168 pruned nodes, max_depth=12
# [161]#011train-rmse:0.133263#011validation-rmse:0.339042
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 654 extra nodes, 184 pruned nodes, max_depth=12
# [162]#011train-rmse:0.132754#011validation-rmse:0.338931
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 124 pruned nodes, max_depth=12
# [163]#011train-rmse:0.132327#011validation-rmse:0.338982
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 528 extra nodes, 116 pruned nodes, max_depth=12
# [164]#011train-rmse:0.131851#011validation-rmse:0.339052
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 118 pruned nodes, max_depth=12
# [165]#011train-rmse:0.131505#011validation-rmse:0.338958
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 770 extra nodes, 198 pruned nodes, max_depth=12
# [166]#011train-rmse:0.130688#011validation-rmse:0.338856
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 596 extra nodes, 158 pruned nodes, max_depth=12
# [167]#011train-rmse:0.130101#011validation-rmse:0.33868
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 142 pruned nodes, max_depth=12
# [168]#011train-rmse:0.129635#011validation-rmse:0.33848
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 622 extra nodes, 206 pruned nodes, max_depth=12
# [169]#011train-rmse:0.129059#011validation-rmse:0.338371
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 636 extra nodes, 214 pruned nodes, max_depth=12
# [170]#011train-rmse:0.128476#011validation-rmse:0.33833
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 666 extra nodes, 232 pruned nodes, max_depth=12
# [171]#011train-rmse:0.12795#011validation-rmse:0.33826
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 598 extra nodes, 162 pruned nodes, max_depth=12
# [172]#011train-rmse:0.12738#011validation-rmse:0.338226
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 124 pruned nodes, max_depth=12
# [173]#011train-rmse:0.126966#011validation-rmse:0.338099
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 72 pruned nodes, max_depth=12
# [174]#011train-rmse:0.126818#011validation-rmse:0.338023
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 526 extra nodes, 140 pruned nodes, max_depth=12
# [175]#011train-rmse:0.126306#011validation-rmse:0.338014
# [23:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 548 extra nodes, 168 pruned nodes, max_depth=12
# [176]#011train-rmse:0.125783#011validation-rmse:0.338023
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 596 extra nodes, 170 pruned nodes, max_depth=12
# [177]#011train-rmse:0.125295#011validation-rmse:0.337896
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 562 extra nodes, 178 pruned nodes, max_depth=12
# [178]#011train-rmse:0.124792#011validation-rmse:0.337894
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 94 pruned nodes, max_depth=12
# [179]#011train-rmse:0.124597#011validation-rmse:0.337803
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 110 pruned nodes, max_depth=12
# [180]#011train-rmse:0.124385#011validation-rmse:0.337828
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 168 pruned nodes, max_depth=12
# [181]#011train-rmse:0.12397#011validation-rmse:0.337668
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 710 extra nodes, 240 pruned nodes, max_depth=12
# [182]#011train-rmse:0.123339#011validation-rmse:0.337703
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 136 pruned nodes, max_depth=12
# [183]#011train-rmse:0.123032#011validation-rmse:0.337651
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 506 extra nodes, 124 pruned nodes, max_depth=12
# [184]#011train-rmse:0.122613#011validation-rmse:0.337557
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 138 pruned nodes, max_depth=12
# [185]#011train-rmse:0.122228#011validation-rmse:0.337332
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 192 pruned nodes, max_depth=12
# [186]#011train-rmse:0.121835#011validation-rmse:0.337254
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 704 extra nodes, 172 pruned nodes, max_depth=12
# [187]#011train-rmse:0.121133#011validation-rmse:0.337124
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 590 extra nodes, 206 pruned nodes, max_depth=12
# [188]#011train-rmse:0.120632#011validation-rmse:0.336988
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 170 pruned nodes, max_depth=12
# [189]#011train-rmse:0.120267#011validation-rmse:0.336925
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 140 pruned nodes, max_depth=12
# [190]#011train-rmse:0.119999#011validation-rmse:0.336883
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 102 pruned nodes, max_depth=12
# [191]#011train-rmse:0.119706#011validation-rmse:0.336821
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 566 extra nodes, 204 pruned nodes, max_depth=12
# [192]#011train-rmse:0.119238#011validation-rmse:0.336866
# [23:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 144 pruned nodes, max_depth=12
# [193]#011train-rmse:0.11892#011validation-rmse:0.336775
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 102 pruned nodes, max_depth=12
# [194]#011train-rmse:0.118764#011validation-rmse:0.336769
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 694 extra nodes, 248 pruned nodes, max_depth=12
# [195]#011train-rmse:0.118092#011validation-rmse:0.336519
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 158 pruned nodes, max_depth=12
# [196]#011train-rmse:0.117734#011validation-rmse:0.336482
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 788 extra nodes, 252 pruned nodes, max_depth=12
# [197]#011train-rmse:0.116954#011validation-rmse:0.336177
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 680 extra nodes, 274 pruned nodes, max_depth=12
# [198]#011train-rmse:0.116383#011validation-rmse:0.336039
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 216 pruned nodes, max_depth=12
# [199]#011train-rmse:0.115944#011validation-rmse:0.336
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 610 extra nodes, 250 pruned nodes, max_depth=12
# [200]#011train-rmse:0.115468#011validation-rmse:0.335923
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 172 pruned nodes, max_depth=12
# [201]#011train-rmse:0.115174#011validation-rmse:0.335986
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 192 pruned nodes, max_depth=12
# [202]#011train-rmse:0.114835#011validation-rmse:0.335981
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 194 pruned nodes, max_depth=12
# [203]#011train-rmse:0.11453#011validation-rmse:0.335777
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 190 pruned nodes, max_depth=12
# [204]#011train-rmse:0.114116#011validation-rmse:0.335826
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 576 extra nodes, 258 pruned nodes, max_depth=12
# [205]#011train-rmse:0.113699#011validation-rmse:0.335926
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 184 pruned nodes, max_depth=12
# [206]#011train-rmse:0.113381#011validation-rmse:0.335882
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 584 extra nodes, 220 pruned nodes, max_depth=12
# [207]#011train-rmse:0.11294#011validation-rmse:0.335724
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 484 extra nodes, 214 pruned nodes, max_depth=12
# [208]#011train-rmse:0.11259#011validation-rmse:0.335655
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 180 pruned nodes, max_depth=12
# [209]#011train-rmse:0.112233#011validation-rmse:0.335612
# [23:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 206 pruned nodes, max_depth=12
# [210]#011train-rmse:0.111814#011validation-rmse:0.335467
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 504 extra nodes, 236 pruned nodes, max_depth=12
# [211]#011train-rmse:0.111453#011validation-rmse:0.335584
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 210 pruned nodes, max_depth=12
# [212]#011train-rmse:0.111064#011validation-rmse:0.335604
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 552 extra nodes, 244 pruned nodes, max_depth=12
# [213]#011train-rmse:0.110607#011validation-rmse:0.335681
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 150 pruned nodes, max_depth=12
# [214]#011train-rmse:0.110317#011validation-rmse:0.335724
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 228 pruned nodes, max_depth=12
# [215]#011train-rmse:0.109948#011validation-rmse:0.335552
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 200 pruned nodes, max_depth=12
# [216]#011train-rmse:0.109615#011validation-rmse:0.335325
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 516 extra nodes, 266 pruned nodes, max_depth=12
# [217]#011train-rmse:0.109187#011validation-rmse:0.335276
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 180 pruned nodes, max_depth=12
# [218]#011train-rmse:0.108986#011validation-rmse:0.335174
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 208 pruned nodes, max_depth=12
# [219]#011train-rmse:0.108629#011validation-rmse:0.335088
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 616 extra nodes, 216 pruned nodes, max_depth=12
# [220]#011train-rmse:0.108071#011validation-rmse:0.335154
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 568 extra nodes, 276 pruned nodes, max_depth=12
# [221]#011train-rmse:0.107562#011validation-rmse:0.335085
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 570 extra nodes, 226 pruned nodes, max_depth=12
# [222]#011train-rmse:0.107085#011validation-rmse:0.33509
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 266 pruned nodes, max_depth=12
# [223]#011train-rmse:0.106739#011validation-rmse:0.33498
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 220 pruned nodes, max_depth=12
# [224]#011train-rmse:0.106436#011validation-rmse:0.334935
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 172 pruned nodes, max_depth=12
# [225]#011train-rmse:0.106157#011validation-rmse:0.334908
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 196 pruned nodes, max_depth=12
# [226]#011train-rmse:0.105903#011validation-rmse:0.334848
# [23:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 224 pruned nodes, max_depth=12
# [227]#011train-rmse:0.105512#011validation-rmse:0.334783
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 234 pruned nodes, max_depth=12
# [228]#011train-rmse:0.10514#011validation-rmse:0.334767
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 222 pruned nodes, max_depth=12
# [229]#011train-rmse:0.104923#011validation-rmse:0.334806
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 524 extra nodes, 246 pruned nodes, max_depth=12
# [230]#011train-rmse:0.104499#011validation-rmse:0.334731
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 472 extra nodes, 204 pruned nodes, max_depth=12
# [231]#011train-rmse:0.104217#011validation-rmse:0.334682
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 572 extra nodes, 232 pruned nodes, max_depth=12
# [232]#011train-rmse:0.103668#011validation-rmse:0.334646
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 272 pruned nodes, max_depth=12
# [233]#011train-rmse:0.103272#011validation-rmse:0.334631
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 214 pruned nodes, max_depth=12
# [234]#011train-rmse:0.102959#011validation-rmse:0.334513
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 238 pruned nodes, max_depth=12
# [235]#011train-rmse:0.102678#011validation-rmse:0.334546
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 250 pruned nodes, max_depth=12
# [236]#011train-rmse:0.102415#011validation-rmse:0.334467
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 158 pruned nodes, max_depth=12
# [237]#011train-rmse:0.10218#011validation-rmse:0.334477
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 290 pruned nodes, max_depth=12
# [238]#011train-rmse:0.101833#011validation-rmse:0.334488
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 312 pruned nodes, max_depth=12
# [239]#011train-rmse:0.101536#011validation-rmse:0.334413
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 280 pruned nodes, max_depth=12
# [240]#011train-rmse:0.101213#011validation-rmse:0.334354
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 554 extra nodes, 314 pruned nodes, max_depth=12
# [241]#011train-rmse:0.100757#011validation-rmse:0.334338
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 284 pruned nodes, max_depth=12
# [242]#011train-rmse:0.100537#011validation-rmse:0.334299
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 188 pruned nodes, max_depth=12
# [243]#011train-rmse:0.100404#011validation-rmse:0.334311
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 262 pruned nodes, max_depth=12
# [244]#011train-rmse:0.100138#011validation-rmse:0.334239
# [23:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 136 pruned nodes, max_depth=12
# [245]#011train-rmse:0.100058#011validation-rmse:0.334193
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 260 pruned nodes, max_depth=12
# [246]#011train-rmse:0.099799#011validation-rmse:0.334097
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 230 pruned nodes, max_depth=12
# [247]#011train-rmse:0.099497#011validation-rmse:0.334071
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 224 pruned nodes, max_depth=12
# [248]#011train-rmse:0.099288#011validation-rmse:0.333987
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 266 pruned nodes, max_depth=12
# [249]#011train-rmse:0.099011#011validation-rmse:0.33393
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 260 pruned nodes, max_depth=12
# [250]#011train-rmse:0.098715#011validation-rmse:0.334006
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 294 pruned nodes, max_depth=12
# [251]#011train-rmse:0.098432#011validation-rmse:0.333915
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 204 pruned nodes, max_depth=12
# [252]#011train-rmse:0.098168#011validation-rmse:0.333907
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 332 pruned nodes, max_depth=12
# [253]#011train-rmse:0.097911#011validation-rmse:0.333919
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 266 pruned nodes, max_depth=12
# [254]#011train-rmse:0.097614#011validation-rmse:0.333898
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 286 pruned nodes, max_depth=12
# [255]#011train-rmse:0.097381#011validation-rmse:0.333842
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 222 pruned nodes, max_depth=12
# [256]#011train-rmse:0.097014#011validation-rmse:0.333687
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 280 pruned nodes, max_depth=12
# [257]#011train-rmse:0.096683#011validation-rmse:0.333575
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 268 pruned nodes, max_depth=12
# [258]#011train-rmse:0.096474#011validation-rmse:0.333629
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 220 pruned nodes, max_depth=12
# [259]#011train-rmse:0.096237#011validation-rmse:0.333578
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 530 extra nodes, 314 pruned nodes, max_depth=12
# [260]#011train-rmse:0.095822#011validation-rmse:0.333591
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 218 pruned nodes, max_depth=12
# [261]#011train-rmse:0.095557#011validation-rmse:0.333476
# [23:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 362 pruned nodes, max_depth=12
# [262]#011train-rmse:0.095219#011validation-rmse:0.333424
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 288 pruned nodes, max_depth=12
# [263]#011train-rmse:0.094974#011validation-rmse:0.333504
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 296 pruned nodes, max_depth=12
# [264]#011train-rmse:0.094609#011validation-rmse:0.333477
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 244 pruned nodes, max_depth=12
# [265]#011train-rmse:0.094376#011validation-rmse:0.333429
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 438 extra nodes, 338 pruned nodes, max_depth=12
# [266]#011train-rmse:0.094058#011validation-rmse:0.333323
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 280 pruned nodes, max_depth=12
# [267]#011train-rmse:0.093851#011validation-rmse:0.33321
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 370 pruned nodes, max_depth=12
# [268]#011train-rmse:0.093519#011validation-rmse:0.333117
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 260 pruned nodes, max_depth=12
# [269]#011train-rmse:0.093303#011validation-rmse:0.333088
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 150 pruned nodes, max_depth=12
# [270]#011train-rmse:0.0932#011validation-rmse:0.333077
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 244 pruned nodes, max_depth=12
# [271]#011train-rmse:0.093088#011validation-rmse:0.333091
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 288 pruned nodes, max_depth=12
# [272]#011train-rmse:0.092834#011validation-rmse:0.333202
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 350 pruned nodes, max_depth=12
# [273]#011train-rmse:0.092498#011validation-rmse:0.333065
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 328 pruned nodes, max_depth=12
# [274]#011train-rmse:0.092295#011validation-rmse:0.333004
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 308 pruned nodes, max_depth=12
# [275]#011train-rmse:0.092123#011validation-rmse:0.332987
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 236 pruned nodes, max_depth=12
# [276]#011train-rmse:0.092008#011validation-rmse:0.332903
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 214 pruned nodes, max_depth=12
# [277]#011train-rmse:0.09187#011validation-rmse:0.332896
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 248 pruned nodes, max_depth=12
# [278]#011train-rmse:0.09168#011validation-rmse:0.332964
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 310 pruned nodes, max_depth=12
# [279]#011train-rmse:0.091357#011validation-rmse:0.332957
# [23:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 332 pruned nodes, max_depth=12
# [280]#011train-rmse:0.091069#011validation-rmse:0.332999
# [23:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 404 pruned nodes, max_depth=12
# [281]#011train-rmse:0.090799#011validation-rmse:0.332956
# [23:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 288 pruned nodes, max_depth=12
# [282]#011train-rmse:0.090632#011validation-rmse:0.333021
# [23:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 266 pruned nodes, max_depth=12
# [283]#011train-rmse:0.09051#011validation-rmse:0.332933
# [23:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 248 pruned nodes, max_depth=12
# [284]#011train-rmse:0.090342#011validation-rmse:0.333017
# [23:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 358 pruned nodes, max_depth=12
# [285]#011train-rmse:0.090117#011validation-rmse:0.333052
# [23:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 392 pruned nodes, max_depth=12
# [286]#011train-rmse:0.089879#011validation-rmse:0.333025
# [23:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 288 pruned nodes, max_depth=12
# [287]#011train-rmse:0.089744#011validation-rmse:0.333092
# Stopping. Best iteration:
# [277]#011train-rmse:0.09187#011validation-rmse:0.332896
#
# Training seconds: 68
# Billable seconds: 68

# %%
xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# WARNING:sagemaker:Using already existing model: xgboost-200606-2327-020-7662f1d1

# %%
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %%
xgb_transformer.wait()
# Out:
# ......................Arguments: serve
# [2020-06-07 00:49:47 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-06-07 00:49:47 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-06-07 00:49:47 +0000] [1] [INFO] Using worker: gevent
# [2020-06-07 00:49:47 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-06-07 00:49:47 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-06-07 00:49:48 +0000] [40] [INFO] Booting worker with pid: 40
# [2020-06-07:00:49:48:INFO] Model loaded successfully for worker : 38
# [2020-06-07:00:49:48:INFO] Model loaded successfully for worker : 39
# [2020-06-07 00:49:48 +0000] [41] [INFO] Booting worker with pid: 41
# [2020-06-07:00:49:48:INFO] Model loaded successfully for worker : 40
# [2020-06-07:00:49:48:INFO] Model loaded successfully for worker : 41
#
# [2020-06-07:00:50:19:INFO] Sniff delimiter as ','
# [2020-06-07:00:50:19:INFO] Determined delimiter of CSV input is ','
# [2020-06-07:00:50:19:INFO] Sniff delimiter as ','
# [2020-06-07:00:50:19:INFO] Determined delimiter of CSV input is ','
# 2020-06-07T00:50:18.975:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-ap-northeast-1-105243015009/xgboost-200606-2327-020-7662f1d1-2020-06-07-00-46-19-444/test_x.csv.out to ML_data/test_x.csv.out

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test_x.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(test_y, predictions)
from sklearn.metrics import f1_score
f1 = f1_score(test_y, predictions)
from sklearn.metrics import precision_score
precision = precision_score(test_y, predictions, average='binary')
from sklearn.metrics import recall_score
recall = recall_score(test_y, predictions, average='binary')
print('\nAccuracy Score:', accuracy)
print('\nF1 Score:', f1)
print('\nPrecision:', precision)
print('\nRecall:', recall)
# Out:
# Accuracy Score: 0.8511931562359297
#
# F1 Score: 0.8813498474241608
#
# Precision: 0.8718039772727273
#
# Recall: 0.8911070780399274
